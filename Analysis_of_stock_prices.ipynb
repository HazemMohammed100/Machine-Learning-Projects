# %% [markdown]
# # 1) Importing the packages

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
plt.style.use('seaborn')

# %% [markdown]
# # 2) Exploring the dataset

# %%
df = pd.read_csv('../Datasets/prices.csv', index_col='date', parse_dates=True)
df.head()
# Out:
#            symbol       close       volume
# date
# 2010-01-04   AAPL  214.009998  123432400.0
# 2010-01-04    ABT   54.459951   10829000.0
# 2010-01-04    AIG   29.889999    7750900.0
# 2010-01-04   AMAT   14.300000   18615100.0
# 2010-01-04   ARNC   16.650013   11512100.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84912 entries, 2010-01-04 to 2016-12-30
# Data columns (total 3 columns):
# symbol    84912 non-null object
# close     84912 non-null float64
# volume    84912 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#               close        volume
# count  84912.000000  8.491200e+04
# mean      42.962139  2.527185e+07
# std       63.250840  3.179535e+07
# min        1.590000  5.990000e+04
# 25%       15.440000  1.023690e+07
# 50%       29.969999  1.597010e+07
# 75%       47.459999  2.795918e+07
# max      707.610001  8.596434e+08

# %%
df.isna().sum()
# Out:
# symbol    0
# close     0
# volume    0
# dtype: int64

# %%
df.symbol.nunique()
# Out:
# 50

# %%
plt.figure(figsize=(5,8))
plt.boxplot(data=df, x='close');

# %%
plt.figure(figsize=(5,8))
plt.boxplot(data=df, x='volume');

# %%
df.plot()
plt.show()

# %%
df.close.plot(kind='hist');

# %%
fig, ax = plt.subplots()
df.plot(ax=ax, figsize=(12,5), linewidth=2, linestyle='--', kind='line')
plt.show()

# %%
df.plot(subplots=True,
linewidth=0.5,
layout=(2, 4),
figsize=(16, 10),
sharex=False,
sharey=False);

# %% [markdown]
# # 1) Importing the packages
